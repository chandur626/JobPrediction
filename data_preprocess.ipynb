# %%
import pandas as pd
import numpy as  np
import re
data=pd.read_csv("mini.csv",encoding='latin-1')
data['sector'][4].split(',')
# Out:
# ['C#',
#  ' ASP.NET',
#  ' SQL',
#  ' JavaScript',
#  ' MVC - C#',
#  ' ASP.NET',
#  ' SQL',
#  ' JavaScript',
#  ' MVC']

# %%
import re
for i in range(0,len(data.index)):
    print(list(set(re.findall(r"[\w']+",data['sector'][i].lower()))))
# Out:
# ['as2', 'edi', 'trustedlink', 'van']
# ['sql', 'netezza', 'etl', 'oracle', 'informatica', 'exchange', 'b2b', 'data']
# ['angular']
# ['dynamics', 'toronto', 'manager', 'usd', 'ax', '135k', 'microsoft', 'project']
# ['net', 'sql', 'c', 'asp', 'mvc', 'javascript']
# ['language', 'visualization', 'python', 'scala', 'machine', 'processing', 'iot', 'analytics', 'java', 'learning', 'deep', 'spark', 'nlp', 'natural', 'industrial', 'predictive', 'data', 'modeling']
# ['agile', 'sql', 'or', 'unix', 'oracle', 'concurrent', 'multi', 'java', 'methodology', 'sdlc', 'linux', 'programming', 'threaded']
# ['administrator', 'linux', 'system']
# ['xactly', 'analyst', 'financial', 'commission', 'sales', 'callidus', 'compensation', 'tuecomp']
# ['application', 'drupal', 'experience', 'strong', 'development', 'in']
# ['tool', 'scripting', 'ssis', 'aws']
# ['operations', 'it', 'pmo', 'pay', 'supporting', 'retail', 'finance', 'is', 't', 'purchase', 'support', 'to']
# ['net', 'c', 'asp', 'html5', 'content', 'javascript', 'management', 'systems']
# ['security', 'networking', 'telecom', 'peripherals', 'printer', 'laptop', 'supervision', 'hardware', 'technician']
# ['wan', 'c', 'networking', 'software', 'engineer', 'development', 'java', 'testing', 'ecommerce', 'programming', 'management', 'project']
# ['analysis', 'reports', 'ad', 'data', 'bi', 'hoc']
# ['specialist', 'personalization']
# ['ariba', 'supply', 'consulting', 'excel', 'development', 'chain', 'recruiter', 'html', 'lifecycle', 'crm', 'sap', 'testing', 'research', 'management', 'http']
# ['java', 'mongodb']
# ['net', 'working', 'with', 'demonstrated', 'interpersonal', 'skills', 'communication', 'and', 'experience', 't', 'verbal', 'salesforce', 'ipc', 'written', 'qualifications', 'ability']
# ['analysis', 'security', 'networking', '7', 'and', 'system', 'administrator', 'recovery', 'ccna', 'backup', 'development', 'hardware', 'exchange', 'windows', 'dns', 'ip', 'tcp', 'systems']
# ['performance', 'networks', 'networking', 'engineer', 'network', 'system', 'scheduling', 'ccie', 'cisco', 'firewall']
# ['java', 'developer']
# ['years', 'it', 'or', 'an', 'systems', '3', 'experience', 'field', 'support', "bachelor's", 'information', 'technology', 'required', 'equivalent', 'work', 'of', 'degree', 'qualifications', 'related', 'in']
# ['sdlc', 'net', 'c', 'asp']
# ['meeting', 'skills', 'and', 'excellent', 'goto', 'excel', 'degree', 'management', 'bachelors', 'project']
# ['or', 'maven', 'rake', 'make', 'ant']
# ['rails', 'mobile', 'on', 'ruby', 'html5', 'aws', 'javascript', 'web']
# ['developer', 'mysql', 'development', 'php', 'linux', 'programming', 'apache']
# ['networking', 'windows', 'wan', 'and', 'servers', 'server', 'backup', 'domain', 'vmware', 'management', 'switching', 'active', 'experience', 'eam', 'lan', 'of', 'support', 'user', 'ip', 've', 'directory', '5', '50', 'environment', 'cisco']
# ['rails', 'frontend', 'on', 'ruby', 'mysql', 'aws', 'development', 'javascript', 'backend']
# ['maven', 'jenkins', 'aws', 'linux', 'devops']
# ['shotgun', 'software', 'unix', 'windows7', 'os', 'linux', 'mac']
# ['analysis', 'application', 'project', 'networking', 'engineer', 'protocols', 'python', 'basic', 'network', 'unix', 'quality', 'computer', 'linux', 'management', 'perl']
# ['db2', 'etl', 'migration', 'vsam', 'data', 'ibm']
# ['sql', 'c', 'basic', 'visual', 'usb', 'serial', 'bluetooth', 'ethernet']
# ['wan', 'c', 'networking', 'software', 'engineer', 'development', 'java', 'testing', 'ecommerce', 'programming', 'management', 'project']
# ['analysis', 'sql', 'intelligence', 'metrics', 'development', 'business', 'requirements', 'research']
# ['java', 'developer']
# ['automation', 'linux', 'aws', 'windows', 'devops']
# ['aem', 'cq5']
# ['manager', 'project']
# ['security', 'software', 'peripherals', 'laptop', 'printer', 'desktop', 'hardware', 'computer', 'technician', 'systems']
# ['contracts', 'ar', 'service', 'coordination', 'uat', 'architect', 'otc', 'solution', 'crp', 'business']
# ['apex', 'solutions', 'data']
# ['agile', 'b2b', 'or', 'drupal', 'tools', 'b', 'b2c', 'cms', 'a']
# ['ios', 'development', 'android', 'mobile']
# ['sql', 'developer']
# ['vrm', 'coso', 'governance', 'risk', 'vendor', 'compliance', 'cobit', 'archer', 'management']
# ['designer', 'ux', 'mobile']
# ['analysis', 'analyst', 'pmp', 'development', 'java', 'lotus', 'project', 'adobe', 'requirements', 'ibm', 'management', 'sql', 'peoplesoft', 'architecture', 'lifecycle', 'business', 'testing', 'http', 'developer', 'risk', 'erp', 'oracle', 'consulting', 'accounting', 'sap', 'materials']
# ['peoplesoft', 'hris', 'taleo']
# ['application', 'web', 'developer']
# ['mura', 'apis', 'java', 'javascript', 'html', 'css']
# ['engineer', 'development', 'software']
# ['telephony', 'communications', 'unified', '365', 'voice', 'office', 'microsoft', 'lync']
# ['suite', 'erp', 'soa', 'financial', 'dodaf', 'togaf', 'cio', 'office', 'microsoft', 'zachman']
# ['shell', 'perl', 'or', 'ruby', 'db2', 'z', 'bash', 'mainframe', 'scripting', 'lpar', 'sysplex', 'java', 'websphere', 'environment', 'os', 'plus']
# ['s', 'r', 'sales', 'collaboration', 'post', 'uc', 'ccie', 'cisco', 'ccnp']
# ['services', 'e', 'suite', 'sharepoint', 'soa', 'service', 'togaf', 'dodaf', 'office', 'g', 'oriented', 'architecture', 'ea', 'framework', 'visio', 'web', 'data', 'microsoft', 'zachman']
# ['engineer', 'design', 'test']
# ['dynamics', 'assistant', 'controller', 'experience', 'gp', 'cpa', 'w']
# ['services', 'amazon', 'puppet', 'scripting', 'aws', 'web', 'linux']
# ['networking', 'administrator', 'windows', 'sms', 'pc', 'wan', 'protocol', 'bridges', 'hardware', 'vmware', 'vpn', 'networks', 'lan', 'ip', 'wireless', 'network', 'routers', 'switches', 'dns', 'cisco', 'tcp']
# ['support', 'desk', 'service']
# ['sql', 'developer', 'citrix', 'database', 'oracle', 'java', 'hardware', 'xml', 'testing']
# ['engineer', 'design', 'test']
# ['net', 'sql', 'c', 'reports', '2010', 'visual', 'server', 'studio', 'crystal', '2008']
# ['automated', 'soapui', 'testing', 'validation', 'data']
# ['designer', 'architectural']
# ['sql', 'intelligence', 'metrics', 'tools', 'python', 'database', 'development', 'business', 'bi', 'project']
# ['services', 'spring', 'hibernate', 'procedures', 'and', 'structure', 'java', 'stored', 'rdbms', 'web', 'triggers', 'core', 'drools', 'data', 'ilog', 'packages']
# ['peoplesoft', 'hris', 'taleo']
# ['analysis', 'net', 'project', 'sql', 'asp', 'software', 'engineer', 'change', 'development', 'soap', 'html', 'xml', 'testing', 'management', 'css']
# ['center', 'cad', 'wan', 'call', 'telecom', 'analyst', 'manager', 'lan', 'switches', 'supervisor', 'cisco', 'management']
# ['drug', 'budget', 'protocol', 'initiation', 'setup', 'cro', 'site', 'trials', 'oncology', 'development', 'management']
# ['complete', 'with', 'on', 'software', 'pmp', 'development', 'project', 'hands', 'and', 'engineers', 'data', 'management', 'facing', 'sql', 'edi', 'experience', 'of', 'work', 'interface', 'sdlc', 'certification', 'familiarity', 'leadership', 'net', 'statements', 'client', 'etl', 'creation']
# ['agile', 'sdk', 'android', 'mysql', 'jira', 'ios', 'development', 'java', 'git']
# ['technician', 'cable']
# ['cable', 'electric']
# ['jquery', 'mysql', 'php', 'css']
# ['rails', 'frontend', 'on', 'ruby', 'mysql', 'aws', 'development', 'javascript', 'backend']
# ['hana', 'architect', 'sap']
# ['developer', 'ios', 'development', 'architecture', 'programming']
# ['consultant', 'bpc', 'sap']
# ['security', 'networking', '7', 'desk', 'help', 'hardware', 'windows', 'technician']
# ['performance', '7', 'tuning', 'drupal']
# ['banking', 'rcm', 'experience', 'ais', 'actimize', 'java', 'domain']
# ['warehouse', 'hadoop', 'architecture', 'spark', 'data', 'big']
# ['mechanical', 'software', 'and', 'mechatronics', 'fmea', 'dfr', 'electrical']
# ['consultant', 'warehouse', 'management', 'sap']
# ['developer', 'perl']
# ['sql', 'dba', 'plsql', 'analyst', 'unix', 'database', 'oracle', 'api', 'troubleshooting', 't', 'linux', 'data']
# ['sql', 'solaris', 'linux', 'python', 'and', 'knowledge', 'of', 'javascript', 'write', 'aix']
# ['sales']
# ['tibco', 'developer']
# ['agile', 'developer', 'metrics', 'manager', 'development', 'testing', 'program', 'management', 'foundation', 'project']
# ['sql', 'cloud', 'db2', 'databases', 'migration', 'and', 'oracle', 'server', 'sybase', 'support', 'installation']
# ['technician', 'pc']
# ['ax2012r3', 'dynamics', 'functional', 'analyst', 'erp', 'implementation', 'ax7', 'ax', 'consultant', 'business']
# ['analysis', 'objects', 'sql', 'intelligence', 'analytical', 'reports', 'skills', 'scripts', 'database', 'release', 'crystal', 'business', 'validation', 'epic']
# ['telecommute', 'firewall', 'fortigate', 'engineer']
# ['net', 'dynamics', 'experience', 'development', 'crm', 'microsoft']
# ['hcm', 'eib', 'integrations', 'studio', 'workday', 'payroll']
# ['rackspa', 'python', 'java', 'html', '3', 'containerized', 'structures', 'platform', 'learning', 'nlp', '2', 'data', 'apps', 'restful', 'optimize', 'docker', 'machine', 'javascript', 'angular', 'css', 'cloud', 'openapis', 'google', 'aws', 'azure', 'js']
# ['sql', 'warehouse', 'analyst', 'etl', 'database', 'pl', 'server', 'business', 'bi', 'data']
# ['analysis', 'it', 'security', 'analytical', 'skills', 'analyst', 'risk', 'quality', 'business', 'research', 'management', 'sms', 'project']
# ['analysis', 'mining', 'intelligence', 'warehouse', 'sql', 'metrics', 'excel', 'development', 'architecture', 'programming', 'business', 'data', 'management']
# ['technician', 'decommissioning', 'i']
# ['express', 'js', 'java', 'javascript', 'node', 'backend']
# ['js', 'frontend', 'side', 'mysql', 'angularjs', 'server', 'development', 'javascript', 'reactjs', 'node', 'backend']
# ['c', 'sdk', 'networking', 'swift', 'ios', 'development', 'objective']
# ['networking', 'service', 'customer', 'ccna', 'hardware', 'windows', 'wireless', 'vmware', 'pc']
# ['an', 'screen', 'background', 'position', 'is', 'sexual', 'and', 'females', 'identity', 'opportunity', 'requires', 'or', 'this', 'of', 'inc', 'minorities', 'drug', 'the', 'completion', 'ciber', 'employer', 'orientat', 'successful', 'gender', 'investigation', 'a', 'equal']
# ['net', 'security', 'c', 'sql', 'asp', 'developer', 'software', 'automated', 'qa', 'engineer', 'server', 'development', 'javascript', 'testing', 'vb', 'project']
# ['operations', 'it', 'manager', 'systems']
# ['automation', 'vsts', 'ui', 'testing']
# ['in', 'cobol', 'mobil', 'and', 'b', 'database', 'desing', 'plus', 's', 'science', 'java', 'javascript', 'html', 'computer', 'apps', 'css']
# ['python', 'help', 'recovery', 'windows', 'scripts', 'capacity', 'project', 'desk', 'antivirus', 'hardware', 'recruiter', 'management', 'security', 'planning', 'printer', 'change', 'php', 'wireless', 'http', 'automated', 'qa', 'switches', 'disaster']
# ['ux', 'metrics', 'qa', 'assurance', 'quality', 'development', 'java', 'testing', 'management', 'project']
# ['edi', 'documents', 'supply', 'chain', 'sap']
# ['7', 'pc', 'windows', 'iphone']
# ['wan', 'ip', 'engineer', 'network', 'lan', 'supervision', 'switches', 'desktop', 'architecture', 'hardware', 'tcp', 'wireless', 'support', 'dns', 'cisco', 'management', 'routers']
# ['project', 'tracking', 'construction', 'cost', 'site', 'civil', 'work', 'excavating', 'degree', 'management', 'cadd', 'engineering']
# ['netezza', 'informatica']
# ['analysis', 'analytical', 'service', 'api', 'development', 'oriented', 'web', 'html', 'salesforce', 'systems', 'sales', 'customer', 'soap', 'design', 'security', 'sql', 'object', 'interface', 'javascript', 'architecture', 'xml', 'user', 'application', 'developer', 'applications']
# ['mississauga', 'ontario', 'toronto', 'quebec', 'montreal', 'azure']
# ['c', 'android', 'developer', 'visual', 'ms', 'java', 'eclipse', 'php', 'studio', 'ide', 'storm']
# ['analysis', 'software', 'python', 'development', 'java', 'html', 'tdd', 'perl', 'agile', 'jenkins', 'database', 'requirements', 'management', 'sql', 'peoplesoft', 'javascript', 'architecture', 'lifecycle', 'business', 'testing', 'http', 'css', 'engineer', 'oracle', 'consulting', 'accounting', 'git', 'sap']
# ['peoplesoft', 'hris', 'taleo']
# ['sql', 'sqr', 'tools', 'financial', 'peoplesoft', 'modules', 'people']
# ['javascript', 'php', 'html', 'jquery', 'css']
# ['network', 'engineer']
# ['application', 'agile', 'sql', 'c', 'page', 'bootstrap', 'html5', 'scrum', 'single', 'development', 'javascript', 'server', 'html', 'gulp', 'knockout', 'angular', 'css']
# ['or', 'tools', 'google', 'sharepoint', 'pharma', 'portfolio', 'biotech', 'saas', 'ms', 'office', 'visio', 'management']
# ['peoplesoft', 'hris', 'taleo']
# ['bank', 'kyc', 'secrecy', 'reports', 'analyst', 'bsa', 'anti', 'laundering', 'currency', 'compliance', 'aml', 'edd', 'transaction', 'money']
# ['application', 'net', 'sql', 'iis', 'asp', 'release', 'server', 'development', 'javascript', 'applications', 'management']
# ['c', 'software', 'operating', 'concepts', 'design', 'embedded', 'systems']
# ['without', 'frontend', 'mobile', 'design', 'patterns', 'ui', 'large', 'scale', 'development', 'javascript', 'for', 'framework', 'a', 'apps', 'systems']
# ['adobe', 'java', 'webservices', 'cq']
# ['sr', 'windows', 'engineer']
# ['microstrategy', 'dw', 'reports', 'development', 'bi']
# ['tibco', 'spotfire']
# ['business', 'analyst', 'improvement', 'process']
# ['in', 'cobol', 'mobil', 'and', 'b', 'database', 'desing', 'plus', 's', 'science', 'java', 'javascript', 'html', 'computer', 'apps', 'css']
# ['analysis', 'application', 'sql', 'developer', 'database', 'servers', 'development', 'soap', 'server', 'testing']
# ['developer', 'certified', 'sdk', 'ellimae']
# ['jquery', 'java', 'javascript']
# ['automation', 'cases', 'manual', 'assurance', 'quality', 'plans', 'testing', 'test']
# ['c', 'ides', 'firmware', 'microcontrollers', 'rtos', 'embedded']
# ['rails', 'automation', 'full', 'on', 'ruby', 'mobile', 'apis', 'saas', 'development', 'javascript', 'web', 'tdd', 'devops', 'applications', 'stack']
# ['hands', 'cto', 'on']
# ['logical', 'sql', 'dba', 'unix', 'database', 'pl', 'oracle', 'administrator', 'stored', 'infrastructure', 'data', 'triggers', 'models', 'design', 'procedure']
# ['python', 'machine', 'r', 'hive', 'learning']
# ['sql', 'with', 'etl', 'oracle', 'quality', 'reporting', 'data']
# ['net', 'c', 'asp', 'webapi', 'angularjs', 'javascript', 'html', 'css', 'js', 'react']
# ['engineer', 'software']
# ['middleware', 'engineer']
# ['specialist', 'data']
# ['net', 'sql', 'c', 'asp', 'foundation', 'visual', 'server', 'team', 'javascript', 'git', 'studio', '4', '6', 'microsoft']
# ['java', 'developer']
# ['net', 'c', 'ifix', 'mes', 'ms', 'controls', 'windows', 'vb', 'design', 'electrical']
# ['axure', 'ux', 'cloud', 'wireframing', 'and', 'rp', 'development', 'prototyping', 'azure', 'design']
# ['time', 'center', 'opening', 'tech', 'data', 'part']
# ['wireframes', 'axure', 'omnigraffe', 'experience', 'cs', 'balasmiq', 'adobse', 'architect', 'visio', 'photoshop', 'user', 'illustrator']
# ['wireframes', 'ux', 'web', 'html', 'ui', 'css']
# ['servicenow', 'ppm']
# ['project', 'security', 'intelligence', 'warehouse', 'metrics', 'director', 'case', 'database', 'system', 'olap', 'architecture', 'business', 'management', 'data', 'modeling', 'http']
# ['analyst', 'data']
# ['support', 'desktop']
# ['technician', 'network', 'i']
# ['spring', 'sql', 'java', 'javascript', 'html', 'css']
# ['performance', 'tuning', 'scripts', 'loadrunner', 'testing', 'test']
# ['analysis', 'security', 'director', 'development', 'research', 'management', 'http']
# ['agile', 'planning', 'javscript', 'integration', 'java', 'jquery']
# ['certified', 'master', 'scrum']
# ['net', 'sql', 'c', 'asp', 'foundation', 'visual', 'server', 'team', 'javascript', 'git', 'studio', '4', '6', 'microsoft']
# ['platform', 'engineer']
# ['sr', 'windows', 'engineer']
# ['hands', 'phone', 'must', 'with', 'on', 'and', 'experience', 'genesys', 'infrastructure', 'reporting', 'have', 'hardware']
# ['net', 'c', 'asp', 'webapi', 'angularjs', 'javascript', 'html', 'css', 'js', 'react']
# ['e', 'graphics', 'designer', 'commerce', 'web', 'html', 'design', 'css']
# ['net', 'sql', 'c', 'agile', 'nhibernate', 'api', 'server', 'oop', 'entity', 'web', 'framework', 'wcf']
# ['networking', 'manager', 'database', 'service', 'customer', 'development', 'recruiter', 'management']
# ['c', 'unix', 'red', 'hat', 'java', 'linux', 'vmware']
# ['net', 'vb']
# ['net', 'gpib', 'c', 'vb', 'engineer', 'power', 'python', 'analog', 'statistics', 'semiconductor', 'op', 'test', 'interface', 'inferential', 'amps', 'management', 'systems']
# ['qlikview']
# ['analyst', 'data']
# ['net', 'sql', 'c', 'visual', 'server', 'studio']
# ['tomcat', 'j2ee', 'hibernate', 'spring', 'unix', 'maven', 'jenkins', 'java', 'cucumber', 'linux']
# ['automation', 'sql', 'linux', 'unix', 'scripting', 'devops']
# ['sfdc', 'edmonton', 'developer', 'integrations', 'com', 'api', 'vf', 'apex', 'implementations', 'salesforce']
# ['analysis', 'analytical', 'plsql', 'unix', 'development', 'java', 'windows', 'scripts', 'subversion', 'control', 'project', 'agile', 'server', 'requirements', 'data', 'management', 'sql', 'asp', 'sdlc', 'scheduling', 'lifecycle', 'business', 'testing', 'vb', 'net', 'developer', 'skills', 'qa', 'version', 'oracle', 'supervision', 'scheduler', 'ado']
# ['card', 'sql', 'tsys', 'tool', 'erwin', 'set', 'ms', 'office', 'chrome', 'toad', 'credit', 'operations', 'data', 'ie', 'big']
# ['devops', 'engineer']
# ['native', 'years', 'application', 'agile', 'android', 'mobile', '3', 'experience', 'ios', 'of', 'development', 'environment', 'preferably', 'in']
# ['engineering', 'engineer', 'risa', 'training', 'autocad', 'civil', 'eit', 'structural', 'certification', 'degree', 'in']
# ['analysis', 'writing', 'technical', 'reporting', 'business', 'requirements', 'management']
# ['sql', 'spring', 'mvc', 'machine', 'java', 'javascript', 'fullstack', 'html', 'development', 'learning', 'css']
# ['ios', 'ui', 'developer']
# ['qa', 'etl', 'analyst', 'testing']
# ['analyst', 'data', 'governance']
# ['analysis', 'it', 'systems', 'analyst', 'risk', 'scripts', 'system', 'quality', 'development', 'modeling', 'test', 'testing', 'business', 'reengineering', 'requirements', 'research', 'management', 'project']
# ['analyst', 'data']
# ['c', 'that', 'technical', 'an', 'background', 'strong', 'candidates', 'must', 'required', 'computer', 'possess', 'these', 'or', 'discipline', 'science', 'vb', 'programming', 'engineering', 'net', 'are', 'skills', 'in']
# ['analyst', 'sharepoint', 'office', 'ms', 'operations', 'microsoft', 'project']
# ['services', 'net', 'j2ee', 'franworks', 'java', 'web']
# ['html5', 'javascript', 'php', 'jquery', 'css']
# ['technician', 'field']
# ['developer', '000k', 'virginia', 'servicenow', '100']
# ['wlan', 'cisco', 'networking', 'wan']
# ['with', 'api', 'excel', 'reporting', 'salesforce', 'extracting', 'from', 'objects', 'years', 'calls', 'and', 'via', 'database', 'com', 'ssis', 'data', 'powerpivot', 'sql', 'experience', 'of', 'services', 'ssrs', 'tools', 'using', 'dataloade', '4']
# ['eng', 'tysons', 'oracle', 'apps', 'iii', 'ebs', 'corner', 'deployment', 'va']
# ['technician', 'helpdesk']
# ['rails', 'on', 'ruby', 'mysql', 'html5', 'javascript', 'css3', 'jquery']
# ['jr', 'admin', 'systems']
# ['services', 'amazon', 'sql', 'esri', 'arcmap', 'skills', 'and', 'gis', 'web']
# ['technician', 'device', 'mobile']
# ['application', 'object', 'mysql', 'development', 'oriented', 'web', 'linux', 'perl']
# ['javascript', 'automotive']
# ['including', 'solutions', 'government', 'tad', 'u', 'reliable', 'federal', 'workforce', 'and', 'delivering', 'pgs', 'agencies', 'specializes', 'contractors', 'their', 'secure', 's', 'inc', 'prime', 'rapidly', 'the', 'marketplace', 'implemented', 'wi', 'to', 'in']
# ['c', 'object', 'algorithm', 'structures', 'system', 'java', 'oriented', 'development', 'design', 'data']
# ['cto', 'developer', 'software', 'python', 'development', 'java', 'javascript', 'html', 'computer', 'sdlc', 'web', 'applications', 'test']
# ['net', 'sql', 'cloud', 'asp', 'azure', 'paas']
# ['application', 'object', 'mysql', 'development', 'oriented', 'web', 'html', 'css', 'javascript', 'linux', 'perl']
# ['netiq', 'developer', 'sr', 'lead']
# ['sharepoint', 'case', 'api', 'test', 'management', 'project']
# ['project', 'analysis', 'monitoring', 'geostructural', 'technical', 'engineer', 'construction', 'geotechnical', 'report', 'development', 'professional', 'business', 'design', 'management', 'pe', 'engineering']
# ['in', 'switching', 'courses', 'networking', 'routing', 'internet', 'dcd', 'certified', 'training', 'dca', 'technologies', 'certification', 'vcp', 'vmware', 'dcv', 'vcap5']
# ['including', 'solutions', 'government', 'tad', 'u', 'reliable', 'federal', 'workforce', 'and', 'delivering', 'pgs', 'agencies', 'specializes', 'contractors', 'their', 'secure', 's', 'inc', 'prime', 'rapidly', 'the', 'marketplace', 'implemented', 'wi', 'to', 'in']
# ['in', 'opportunity', 'excellent', 'auburn', 'seeburger', 'b2b', 'consultant']
# ['rochelle', 'network', 'specialist', 'new', 'jr']
# ['keyword', 'or', 'search', 'bid', 'ad', 'copy', 'analytics', 'marketing', 'online', 'campaigns', 'making']
# ['with', 'experience', 'hybris', 'strong', 'management', 'project']
# ['application', 'call', 'on', 'engineer', 'rotation', 'voice', 'cluster', 'cucm', 'support', 'cisco']
# ['scala', 'docker', 'aws', 'go', 'golang']
# ['cad', 'inventor', 'exp', 'autodesk', 'engineering', 'year', 'cabinet', 'experience', 'desired', 'degree', '3d', 'autocad', 'design', 'woodworking', '2d', '2']
# ['intelligence', 'manager', 'sales', 'development', 'hardware', 'html', 'business', 'cisco', 'management', 'http']
# ['safecopy', 'sharepoint', 'office', 'ediscovery', 'ms']
# ['erlang', 'developer']
# ['optimization', 'application', 'market', 'boiler', 'experience', 'emissions', 'large', 'system', 'strong', 'product', 'background', 'bringing', 'development', 'to', 'low']
# ['application', 'performance', 'c', 'sql', 'developer', 'qa', 'database', 'system', 'test', 'development', 'hardware', 'javascript', 'web', 'computer', 'business', 'requirements', 'applications', 'systems']
# ['erwin', 'modeler', 'release', 'architect', '9', 'data', 'modeling']
# ['goods', 'consumer', 'package', 'retail', 'sales', 'analytics']
# ['application', 'object', 'mysql', 'development', 'oriented', 'web', 'html', 'css', 'javascript', 'linux', 'perl']
# ['workflows', 'configuration', 'architect', 'salesforce', 'integration', 'design']
# ['wordpress', 'sql', 'drupal', 'ajax', 'javascript', 'php', 'html', 'jquery', 'w3c', 'css']
# ['strongly', 'licensed', 'knowledge', 'someone', 'sales', 'prefer', 'benefit', 'who', 'hr', 'is', 'az', 'in']
# ['seeburger', 'edi', 'b2b', 'automative']
# ['security', 'wan', 'networks', 'telecom', 'analyst', 'service', 'lan', 'customer', 'recovery', 'hardware', 'disaster', 'linux']
# ['ccie']
# ['including', 'solutions', 'government', 'tad', 'u', 'reliable', 'federal', 'workforce', 'and', 'delivering', 'pgs', 'agencies', 'specializes', 'contractors', 'their', 'secure', 's', 'inc', 'prime', 'rapidly', 'the', 'marketplace', 'implemented', 'wi', 'to', 'in']
# ['it', 'healthcare', 'ccna', 'citrix', '2010', 'clinical', 'ccie', 'tcp', '2007', 'active', 'o365', 'environments', 'troubleshooting', 'emr', 'ip', 'microsoft', 'directory', 'worfklow', 'switches', 'exchange', 'routers']
# ['manager', 'icoms', 'csg', 'amdocs', 'ecommerce', 'test']
# ['front', 'development', 'javascript', 'js', 'end', 'angular']
# ['cto', 'developer', 'software', 'python', 'development', 'java', 'javascript', 'html', 'computer', 'sdlc', 'web', 'applications', 'test']
# ['hvac', 'ufad', 'tdv', 'trace', 'build', 'autocad', 'db', 'delivery', 'project', 'ipd', 'system', 'equivalent', 'value', 'design', 'mechanical', 'or', 'target', 'experience', 'doas', 'trane', 'tvd', 'revit', 'integrated', 'alternate', 'pe']
# ['ssrs', 'sql', 'report']
# ['sql', 'dynamics', 'ssrs', 'integration', 'database', 'implementation', 'scripting', 'manager', 'server', 'great', 'schema', 'plains', 'econnect', 'microsoft', 'upgrade']
# ['application', 'performance', 'c', 'sql', 'developer', 'qa', 'database', 'system', 'consult', 'test', 'development', 'hardware', 'javascript', 'web', 'business', 'requirements', 'applications', 'systems']
# ['analysis', 'gap', 'risk', 'processes', 'business']
# ['seeburger', 'edi']
# ['sql', 'scm', 'analyst', 'supply', 'pl', 'oracle', 'chain', 'manufacturing', 'business', 'management']
# ['support', 'helpdesk']
# ['administrator', 'sfdc', 'salesforce', 'tempe']
# ['including', 'solutions', 'government', 'tad', 'u', 'reliable', 'federal', 'workforce', 'and', 'delivering', 'pgs', 'agencies', 'specializes', 'contractors', 'their', 'secure', 's', 'inc', 'prime', 'rapidly', 'the', 'marketplace', 'implemented', 'wi', 'to', 'in']
# ['regulations', 'red', 'network', 'hat', 'troubleshooting', 'linux', 'ip', 'nerc', 'tcp']
# ['net', 'sql', 'c', 'mvc', 'visual', 'api', 'server', 'entity', 'javascript', 'web', 'studio', 'tfs', 'framework']
# ['charts', 'gantt', 'office', 'autocad', 'microsoft']
# ['websphere', 'commerce']
# ['illustrator', 'requirejs', 'jasmine', 'nodejs', 'grunt', 'scss', 'jquery', 'knockout', 'bower', 'foundation']
# ['shell', 'dba', 'db2', 'unix', 'script', 'linux']
# ['strategy', 'performance', 'micro', '7', 'tuning', 'db2', 'unix', 'etl', 'database', 'informatica', 'administrator', '9', 'linux', 'golden', 'gate']
# ['hrms', 'cove', '0', 'peoplesoft', 'hr', '9']
# ['solutions', 'mechanisms', 'procedures', 'session', 'develop', 'reliable', 'performance', 'robust', 'locking', 'production', 'system', 'high', 'stored', 'live', 'sql', 'tuning', 'complex', 'multi', 'environments', 'transaction', 'pl', 'oracle', 'to', 'in']
# ['sql', 'hadoop', 'software', 'nosql', 'hive', 'saas', 'spark', 'data', 'big']
# ['it', 'team', 'siem', 'systems', 'response', 'cert', 'scripting', 'system', 'computer', 'management', 'security', 'ticketing', 'cirt', 'networks', 'or', 'log', 'hardening', 'workflow', 'automation', 'emergency', 'environment']
# ['j2ee', 'with', 'developer', 'commerce', 'websphere']
# ['python', 'xml', 'c', 'perl']
# ['seo', 'google', 'analytics', 'marketing', 'digital']
# ['analysis', 'mixed', 'optimization', 'software', 'service', 'sets', 'predictive', 'project', 'concepts', 'analyzing', 'projects', 'data', 'management', 'analytics', 'saas', 'modeling', 'mix', 'large', 'statistical', 'self', 'marketing', 'applications']
# ['scala', 'java', 'cloudera', 'hadoop']
# ['python', 'c', 'android']
# ['j2ee', 'cloud', 'hadoop', 'saas', 'computing', 'java', 'ecosystem', 'data', 'big']
# ['services', 'amazon', 'sql', 'ruby', 'apis', 'web', 'linux', 'rest']
# ['fea', 'optics', 'solidworks', 'assembles', 'optomechancial']
# ['j2ee', 'client', 'maven', '11', 'oracle', 'implementation', 'personalization', 'java', 'architecture', 'modules', 'design', 'atg', 'ant', 'delivery']
# ['xi52', 'datapower', 'websphere', 'firmware', 'gateway', '7', 'power', 'and', 'sftp', 'script', 'wsrr', 'data', 'ibm', 'security', 'xsl', 'manager', 'xquery', 'x', 'integration', 'access', 'version', 'appliance', 'mqfte', 'mq']
# ['site', 'civil', 'layout', 'conceptual', 'autocad', 'design', 'engineering']
# ['adobe', 'sql', 'etl', 'unica', 'campaign', 'management']
# ['with', 'threading', 'input', 'exposure', 'complex', 'to', 'activities', 'high', 'multi', 'architecture', 'managing', 'environments', 'applications', 'throughput']
# ['interfaces', 'c', 'instrumentation', 'or', 'remoting', 'development', 'windows', 'computer', 'device', 'wcf']
# ['active', 'directory', 'flexera', 'configuration', 'adminstudio', 'mdm', 'sccm', 'powershell']
# ['planning', 'drm', 'hyperion', 'oracle']
# ['drg', 'drm', 'oracle']
# ['diagnose', 'network', 'iot', 'telematics', 'oem', 'device', 'issues', 'technology', 'operation']
# ['pi', 'sap', 'engineer']
# ['cobol', 'mvs', 'cics', 'gui', 'ims', 'qa', 'unix', 'programmer', 'excel', 'jcl', 'tester', 'lotus', 'management', 'tso', 'notes']
# ['in', 'with', 'full', 'developers', 'and', 'background', 'experience', 'ops', 'java', 'senior', 'dev', 'stack', 'good']
# ['claims', 'causality', 'insurance', 'administration', 'property']
# ['hire', 'dba', 'direct', 'perm', 'oracle', 'fulltime']
# ['data', 'architect', 'insurance']
# ['tools', 'system', 'verification', 'uvm', 'simulation', 'verilog', 'ethernet', 'asic', 'eda']
# ['analysis', 'project', 'mechanical', 'aerospace', 'research', 'supply', 'excel', 'development', 'chain', 'testing', 'exchange', 'programming', 'management', 'aeronautical', 'http']
# ['software', 'entertainment', 'analyst', 'business', 'requirements', 'payroll', 'management', 'project']
# ['application', 'agile', 'net', 'networking', 'csm', 'based', 'scrum', 'science', 'java', 'web', 'computer']
# ['dashboard', 'cobol', 'a', '2e', 'synon', 'plex', 'experience', 'java', 'ca', 'obsydian', 'portal', 'plus']
# ['mysql', 'javascript', 'php']
# ['rails', 'on', 'ruby', 'linux', 'grape']
# ['analysis', 'security', 'risk', 'cissp', 'hardware', 'research', 'management', 'http']
# ['mysql', 'html5', 'api', 'ajax', 'javascript', 'php', 'json', 'xml', 'css3', 'jquery', 'css']
# ['puppet', 'amazon', 'services', 'ruby', 'python', 'chef', 'aws', 'web', 'linux', 'devops']
# ['networking', 'technical', 'reports', 'hyperv', 'i', 'windows', 'administration', 'os', 'documentation', 'systems', 'speed', 'wan', '3par', 'and', 'system', 'server', 'plans', 'infrastructure', 'hardware', 'for', 'vmware', 'vpn', 'racking', '2012', 'raid', 'active', 'disk', 'lan', 'support', 'storage', 'ip', 'r2', 'directory', 'hp', 'network', 'cabling', '2008', 'enhancement', 'tcp']
# ['analysis', 'development', 'hardware', 'simulation', 'validation', 'modeling', 'http']
# ['healthcare', 'cssa', 'pega', 'java', 'framework', 'webservices', 'upgrade']
# ['optimization', 'identify', 'missing', 'like', 't', 'administration', 'powershell', 'performance', '3par', 'and', 'indexes', 'server', 'for', 'design', 'vmware', 'apps', '2012', 'sql', 'active', 'writing', 'upgrading', 'products', 'queries', 'issues', 'troubleshooting', 'optimizing', 'storage', 'directory', '2016', 'to', 'errors']
# ['project', 'lead', 'sap', 'consultant', 'systems']
# ['dboracle', 'asm', 'dba', 'views', 'rman', '12c', 'oms', 'lead', 'oracle', 'oem', 'installation', 'a', 'materialized']
# ['puppet', 'amazon', 'services', 'ruby', 'python', 'chef', 'aws', 'web', 'linux', 'devops']
# ['xenapp', 'vmware', 'windows', 'citrix']
# ['net', 'woodland', 'developer', 'hills', 'job', 'ca', 'vb', 'in']
# ['games', 'scripting']
# ['nexus', 'asa', 'software', '4510', 'series', '3850', '4400', 'controllers', 'and', 'ccie', 'ccnp', 'balancer', '3900s', 'load', 'a10', 'lan', 'zen', 'wireless', 'appliance', 'network', '3500', 'wsa', 'sonicwall', 'switches', 'nsa', '3750', 'balancers', 'cisco', '2960', 'routers']
# ['windows']
# ['mockups', 'marionette', 'slick', 'css3', 'lodash', 'photoshop', 'babel', 'agile', 'save', '7', 'and', 'backbone', 'jquery', 'html5', 'scrum', 'javascript', 'es6', 'react', 'images', 'sass', 'analyze', 'psd', 'js']
# ['alignment', 'optical', 'mode', 'alignement', 'fiber', 'single', 'passive', 'packaging']
# ['analysis', 'laboratory', 'cad', 'mechanical', 'aerospace', 'physics', 'project', '3d', 'development', 'sap', 'testing', 'cae', 'research', '2d', 'http']
# ['net', 'sql', 'c', 'asp', 'server', 'javascript', 'html', 'css']
# ['with', 's4', 'experience', 'lead', 'basis', 'sap', 'hana']
# ['developer', 'senior', 'informatica']
# ['see', 'description', 'job']
# ['years', 'dba', 'level', 'an', 'experience', 'enterprise', 'as', 'of', 'sybase', 'environment', '8', 'a', 'in']
# ['python', 'to', 'new', 'product', 'of', 'architecture', 'contribute', 'publications', 'products', 'programming', 'management', 'systems']
# ['sql', 'etl', 'erwin', 'modeler', 'oracle', 'architecture', 'data']
# ['project', 's4hana', 'ps', 'eto', 'sap', 'e2e', 'pi', 'systems']
# ['hana', 'sap']
# ['on', 'unstructured', 'single', 'reporting', 'web', 'siem', 'systems', 'and', 'identity', 'infrastructure', 'intrusion', 'data', 'structured', 'management', 'security', 'tuning', 'databases', 'cissp', 'testing', 'application', 'access', 'sign', 'detection', 'network', 'penetration']
# ['application', 'restful', 'spring', 'hibernate', '7', 'developing', 'sql', 'database', 'frameworks', 'science', 'queries', 'interface', 'java', '1', 'web', 'computer', 'user']
# ['analysis', 'security', 'openview', 'cissp', 'supervision', 'switches', 'hardware', 'acs', 'management', 'cisco', 'ccnp', 'routers', 'http']
# ['brd', 'analyst', 'financial', 'accounting', 'business']
# ['performance', 'benchmarking', 'addressing', 'distributed', 'routing', 'network', 'synchronization', 'system', 'simulation', 'architecture', 'topologies', 'computer', 'arbitration', 'design', 'control', 'systems']
# ['analysis', 'validation', 'hardware', 'http']
# ['less', 'typescript', 'sass', 'flow', 'bootstrap', 'html5', 'css', 'js', 'rest', 'react']
# ['udb', 'dba', 'db2', 'unix', 'windows', 'data', 'lunix', 'engineering']
# ['python', 'machine', 'learning', 'r']
# ['html5', 'zend', 'magento', 'javascript', 'php', 'community', 'css3', 'ecommerce']
# ['analysis', 'sql', 'migrations', 'etl', 'database', 'pl', 'oracle', 'cleansing', 'server', 'conversion', 'validation', 'data']
# ['c', 'qml', 'gui', 'linux', 'oop', 'development', 'qt5', 'qt4', 'design']
# ['bgp', 'balancing', 'mpls', 'ospf', 'juniper', 'nexus', 'load', 'python', 'mx960', '7k', '5k', 'cisco', 'routers', 'perl']
# ['debugging', 'analysis', 'performance', 'writing', 'plans', 'simulation', 'design', 'documentation', 'test']
# ['sql', 'spring', 'mysql', 'development', 'java', 'backend']
# ['photoshop', 'sketch', 'or', 'illustrator']
# ['application', 'net', 'it', 'sql', 'access', 'developer', 'telecom', 'database', 'oracle', 'pl', 'consulting', 'server', 'vbscript', 'windows', 'vb', 'applications', 'management', 'test']
# ['vc', 'sd', 'sap']
# ['front', 'mysql', 's', 'lamp', 'backbone', 'development', 'javascript', 'php', 'framework', 'linux', 'end', 'angular']
# ['security', 'networking', 'http', 'cissp', 'development', 'project']
# ['pega']
# ['application', 'intelligence', 'ux', 'research', 'development', 'architecture', 'business', 'applications', 'management', 'engineering']
# ['octopus', 'working', 'with', 'internal', 'auditors', 'code', 'jira', 'and', 'deploy', 'release', '3rd', 'controls', 'for', 'party', 'reporting', 'unexpected', 'management']
# ['product', 'designer', 'ux', 'ui']
# ['security', 'networking', 'protocols', 'systems', 'http', 'system', 'ios', 'administrator', 'windows', 'linux', 'research', 'project']
# ['c', 'mvc', 'software', 'like', 'mappers', 'mssql', 'es5', 'database', 'design', 'object', 'asp', 'or', 'continuous', 'webapi', 'javascript', 'best', 'integration', 'angular', 'practices', 'react', 'net', 'modern', 'patterns', '5', 'frameworks', 'soa', 'relational', '4']
# ['adobe', 'middleware', 'engineer', 'experience', 'mgr']
# ['s4', 'basis', 'charm', 'sap', 'hana']
# ['front', 'ux', 'designer', 'and', 'visual', 'product', 'development', 'design', 'end', 'ui', 'interaction']
# ['optimization', 'identify', 'missing', 'like', 't', 'administration', 'powershell', 'performance', '3par', 'and', 'indexes', 'server', 'for', 'design', 'vmware', 'apps', '2012', 'sql', 'active', 'writing', 'upgrading', 'products', 'queries', 'issues', 'troubleshooting', 'optimizing', 'storage', 'directory', '2016', 'to', 'errors']
# ['c', 'cloud', 'distributed', 'python', 'computing', 'infrastructure', 'systems']
# ['center', 'network', 'data', 'engineer']
# ['middleware', 'engineer', 'axway']
# ['shell', 'amazon', 'mysql', 'centos', 'ec2', 'casti', 'server', 'php', 'dell', 'ubuntu', 'ganglia', 'nagios', 'linux', 'cassandra', 'mongodb', 'opennms', 'perl']
# ['edi', 'coordinator']
# ['years', 'it', 'security', 'an', 'engineer', 'experience', 'as', 'of', '4']
# ['analysis', 'security', 'cad', 'mechanical', 'element', 'finite', 'hardware', 'modeling', 'testing', 'autocad', 'materials', 'design', 'http']
# ['ios', 'blackbox', 'development', 'modules']
# ['shell', 'amazon', 'mysql', 'centos', 'ec2', 'casti', 'server', 'php', 'dell', 'ubuntu', 'ganglia', 'nagios', 'linux', 'cassandra', 'mongodb', 'opennms', 'perl']
# ['mechanical', 'aerospace', 'software', 'development', '3d', 'testing', 'modeling', 'http']
# ['excellence', 'process', 'black', 'belt', 'certified']
# ['front', 'ux', 'user', 'experience', 'product', 'interface', 'programming', 'design', 'end', 'ui', 'interaction']
# ['openstack', 'cloud', 'python', 'chef', 'scripting', 'infrastructure', 'linux', 'vmware']
# ['speed', 'sas', 'sata', 'pcie', 'high', 'hardware', 'design']
# ['agile', 'security', 'c', 'developer', 'software', 'automated', 'engineer', 'algorithm', 'ms', 'development', 'hardware', 'architecture', 'mathematical', 'office', 'testing', 'windows', 'programming', 'http']
# ['agile', 'spring', 'product', 'java', 'javascript', 'development']
# ['wordpress', 'linux', 'source', 'mysql', 'red', 'hat', 'magento', 'javascript', 'php', 'subversion', 'jquery', 'ecommerce', 'control', 'management', 'project']
# ['ui', 'unity', 'kit', 'unity3d']
# ['java', 'bootstrap', 'ruby', 'html']
# ['c', 'android', 'qml', 'gui', 'linux', 'mobile', '11', 'ios', 'oop', 'development', 'qt5', 'qt4', 'design', 'ip', 'tcp']
# ['services', 'ajax', 'java', 'javascript', 'web', 'html', 'core', 'rest']
# ['js', 'wireframes', 'front', 'prototypes', 'ux', 'd3', 'html5', 'development', 'javascript', 'ups', 'ext', 'php', 'css3', 'mock', 'end']
# ['dba', 'ms', 'sql']
# ['front', 'j2ee', 'mobile', 'experience', 'html5', 'lead', 'angularjs', 'development', 'java', 'architect', 'javascript', 'css3', 'jquery', 'end', 'apps']
# ['c', 'python', 'alarm', 'systems', 'monitoring', 'perl', 'performance', 'operating', 'and', 'snmp', 'management', 'real', 'oam', 'or', 'sdlc', 'testing', 'embedded', 'unit', 'time', 'event', 'linux']
# ['nand', 'flash', 'development', 'firmware', 'storage', 'pcie']
# ['analysis', 'free', 'custom', 'writing', 'optical', 'tools', 'systems', 'technical', 'reports', 'zemax', 'beam', 'sensor', 'steering', 'space', 'communication', 'temperature', 'design', 'control', 'components']
# ['js', 'wireframes', 'front', 'prototypes', 'ux', 'html5', 'ajax', 'development', 'javascript', 'ups', 'ext', 'css3', 'jquery', 'photoshop', 'mock', 'end']
# ['qt4', 'c', 'networking', 'linux', 'gui', 'qml', 'development', 'qt5', 'protocols', 'design']
# ['marketing', 'program', 'manager']
# ['intelligence', 'sas', 'biotechnology', 'cognos', 'manager', 'fda', 'excel', 'development', 'quality', 'assurance', 'supervision', 'business', 'validation', 'programming', 'management', 'project']
# ['python', 'jenkins', 'docker', 'r', 'javascript', 'postgresql']
# ['producer', 'web']
# ['python', 'machine', 'java', 'learning', 'requirements']
# ['css3', 'jquery', 'javascript', 'html5']
# ['bom', 'outside', 'wip', 'processing', 'mrp', 'quality', 'om', 'inv', 'shipping']
# ['methodologies', 'agile', 'manager', 'coodinator', 'pmbok', 'jr', 'project']
# ['restful', 'javascript', 'nodejs']
# ['years', '10', 'with', 'switching', 'engineer', 'routing', 'very', 'experience', 'network', 'strong', 'as', 'of', 'a']
# ['civil3d', 'civil', 'development', 'land', 'engineering']
# ['j2ee', 'spring', 'mvc', 'angularjs', 'java', 'javascript']
# ['regulatory', 'solutions', 'life', 'space', 'science', 'business']
# ['restful', 'sql', 'mobile', 'ssp', 'python', 'nosql', 'scala', 'app', 'development', 'java', 'dsp']
# ['reservation', 'crs', 'system', 'central']
# ['rails', 'ruby', 'on', 'python', 'mysql', 'javascript']
# ['agile', 'or', 'knowledge', 'content', 'management']
# ['services', 'amazon', 'linux', 'video', 'aws', 'space', 'java', 'web', 'online', 'grails']
# ['content', 'strategist']
# ['software', 'mac', 'management', 'javascript', 'php', 'os', 'file', 'mongodb', 'systems']
# ['metrics', 'database', 'manager', 'assurance', 'excel', 'development', 'quality', 'management', 'project']
# ['engineer', 'full', 'stack', 'software']
# ['chm']
# ['ux', 'sdk', 'android', 'science', 'java', 'computer', 'degree']
# ['c', 'android', 'qml', 'gui', 'linux', 'mobile', '11', 'ios', 'oop', 'development', 'qt5', 'qt4', 'design', 'ip', 'tcp']
# ['security', 'sql', 'dba', 'mysql', 'database', 'oracle', 'consulting', 'server', 'development', 'administration', 'scripts', 'validation', 'management']
# ['j2ee', 'hibernate', 'java', 'spring']
# ['j2ee', 'hibernate', 'spring', 'jboss', 'servlets', 'junit', 'apache', 'java', 'javascript', 'js', 'angular']
# ['leader', 'party', 'third', 'accessories']
# ['c', 'ux', 'swift', 'ios', 'objective']
# ['sip', 'voip', 'certification', 'ccie', 'protocols', 'ccnp']
# ['drug', 'pq', 'mechanical', 'pen', 'gdp', 'engineer', 'device', 'iq', 'and', 'medical', 'solidworks', 'injectors', 'fda', 'qsr', 'needle', 'validation', 'oq', 'fmea', 'devices', 'delivery']
# ['tcl', 'physical', 'compiler', 'floorplanning', 'icc', 'soc', 'design', 'rtl', 'asic', 'perl']
# ['financial', 'oracle', 'p2p', 'ebs', 'o2c']
# ['sql', 'developer']
# ['c', 'ruby', 'tcpdump', 'jenkins', 'aws', 'java', 'git', 'wireshark']
# ['with', 'c', 'swift', 'experience', 'frameworks', 'x', 'os', 'objective']
# ['time', 'full']
# ['services', 'process', 'bpm', 'sharepoint', 'executive', 'hunter', 'account', 'enterprise', 'sales', 'office', '365', 'business', 'solution', 'management']
# ['security', 'software', 'peripherals', 'supervision', 'hardware', 'computer', 'technician', 'systems']
# ['javascript']
# ['python', 'machine', 'r', 'analytics', 'learning', 'science', 'data']
# ['services', 'restful', 'nginx', 'nosql', 'apis', 'javascript', 'web', 'html', 'intellij', 'git', 'linux', 'technologies', 'nodejs', 'css']
# ['analysis', 'application', 'it', 'analytical', 'systems', 'erp', 'manager', 'siebel', 'system', 'change', 'quality', 'jde', 'sdlc', 'sap', 'computer', 'crm', 'salesforce', 'testing', 'management', 'project']
# ['cmake', 'c', 'or', 'ompl', 'python', 'operating', 'pcl', 'opencv', 'system', 'robot', 'robotics', 'ros', 'moveit', 'linux', 'sbpl']
# ['devices', 'process', 'medical', 'solidworks', 'plastics', 'validation', 'engineering']
# ['services', 'sql', 'c', 'python', 'financial', 'server', 'java', 'tdd', 'linux']
# ['oop', 'c', 'ood']
# ['analytics', 'quality', 'engineer']
# ['rails', 'services', 'on', 'ruby', 'web', 'rest']
# ['with', 'warehouse', 'powerpoint', 'portfolio', 'finance', 'excel', 'bs', 'advanced', 'systems', 'years', 'controlling', '3', 'knowledge', 'and', 'or', 'experience', 'word', 'ba', 'business', 'depth', 'erp', '5', 'environment', 'sap', 'a', 'in']
# ['shell', 'bioinformatics', 'tools', 'bash', 'python', 'scripting']
# ['years', 'it', 'with', 'and', 'experience', '5', 'communications', 'change', 'of', 'management']
# ['tableau', 'hadoop', 'visualization', 'tools', 'analytics', 'reporting', 'data']
# ['c', 'elasticsearch', 'redis', 'java', 'spark', 'mongodb']
# ['preferred', 'experience', 'care', 'heath', 'organization', 'a', 'is', 'in']
# ['j2ee', 'hibernate', 'spring', 'jboss', 'servlets', 'junit', 'apache', 'java', 'javascript', 'js', 'angular']
# ['time', 'full']
# ['software', 'product', 'development', 'b2b', 'management']
# ['project', 'performance', 'manager', 'api', 'ibm', 'management', 'engineering']
# ['application', 'c', 'protocol', 'protocols', 'unix', 'cifs', 'structures', 'layer', 'management', 'algorithms', 'storage', 'file', 'data', 'smb', 'systems']
# ['webex', 'or', 'avaya', 'skype', 'voip', 'polycom', 'for', 'business', 'cisco']
# ['sacramento', 'hire', 'or', 'developer', 'gui', 'direct', 'experience', 'contract', 'job', 'user', 'to', 'in']
# ['sql', 'machine', 'learning', 'matlab', 'modeling']
# ['laravel', 'elasticsearch', 'plus', 'javascript', 'php', 'html', 'jquery', 'angular', 'css']
# ['antonio', 'engineer', 'contract', 'san', 'electrical']
# ['security', 'sql', 'dba', 'mysql', 'database', 'oracle', 'consulting', 'server', 'development', 'administration', 'scripts', 'validation', 'management']
# ['services', 'restful', 'java', 'aws']
# ['secuirty', 'aws']
# ['unity', 'ngui', 'kit', 'unity3d', 'ca', 'layer', '2dtoolkit', 'ui']
# ['css3', 'javascript', 'html5']
# ['services', 'restful', 'java', 'aws']
# ['ui', 'visual', 'designer']
# ['rails', 'on', 'ruby', 'mysql', 'html5', 'javascript', 'css3', 'jquery']
# ['services', 'spring', 'hibernate', 'or', 'mysql', 'java', 'web', 'postgresql']
# ['mining', 'techniques', 'object', 'machine', 'learning', 'oriented', 'algorithims', 'nlp', 'text', 'programming']
# ['tools', 'python', 'unix', 'continuous', 'javascript', 'go', 'integration', 'linux']
# ['c', 'kernel', 'unix', 'internals', 'linux']
# ['ms', 'dbms', 'sql', 'oracle']
# ['banking', 'clarify', 'software', 'english', 'technical', 'college', 'training', 'financial', 'product', 'word', 'excel', 'office', 'documentation', 'writer', 'microsoft']
# ['software', 'file', 'x', 'management', 'javascript', 'php', 'os', 'mac', 'mongodb', 'systems']
# ['star', 'sql', 'olap', 'rolap', 'schema', 'molap']
# ['security', 'network', 'diagrams', 'symantec', 'centrify', 'design', 'deployment']
# ['protocols', 'diagnostic', 'robotic']
# ['aws', 'java', 'ec2']
# ['express', 'rails', 'ux', 'ruby', 'on', 'django', 'javascript']
# ['time', 'full']
# ['developer', 'engineer', 'metrics', 'software', 'network', 'research', 'other', 'product', 'san', 'excel', 'hardware', 'storage', 'ip', 'management', 'engineering']
# ['sql', 'c', 'spring', 'java', 'spark', 'mongodb']
# ['analysis', 'molded', 'devices', 'injection', 'medical', 'solidworks', 'plastics', 'autocad', 'root', 'cause']
# ['agile', 'restful', 'mobile', 'apis', 'html', 'testing', 'css']
# ['bash', 'frameworks', 'bamboo', 'scrum', 'redis', 'oop', 'soap', 'json', 'xml', 'kanban', 'rest', 'doctrine']
# ['laboratory', 'agile', 'glp', 'or', 'process', 'gmp', 'lims', 'development']
# ['net', 'asp', 'databases', 'mvc', 'version', 'javascript', 'json', 'relational', 'git', 'jquery', 'knockout', 'control', 'angular']
# ['c', 'threading', 'swift', 'frameworks', 'x', 'multi', 'java', 'os', 'mac', 'objective']
# ['supervision', 'excel', 'management']
# ['laravel', 'elasticsearch', 'plus', 'javascript', 'php', 'html', 'jquery', 'angular', 'css']
# ['mixed', 'etc', 'hibernate', 'spring', 'agile', 'devices', 'signal', 'junit', 'frameworks', 'backbone', 'amber', 'product', 'javascript', 'jvm', 'js', 'core', 'angular', 'engineering']
# ['networking', 'service', 'recovery', 're', 'windows', 'os', 'project', 'intelligence', 'customer', 'hardware', 'technician', 'management', 'security', 'apple', 'x', 'scheduling', 'business', 'engineering', 'director', 'erp', 'assurance', 'quality', 'disaster', 'cisco']
# ['channel', 'idoc', 'edi', 'sap', 'crm', 'management']
# ['c', 'qml', 'gui', 'linux', 'oop', 'development', 'qt5', 'qt4', 'design']
# ['net', 'c', 'mvc', 'aws', 'entity', 'javascript', 'framework']
# ['product', 'b2b', 'management', 'gaming']
# ['c', 'python', 'algorithm', 'and', 'opencv', 'cv', 'implementation', 'machine', 'development', 'for', 'robotics', 'ros', 'learning', 'design']
# ['mean', 'full', 'stack', 'developer']
# ['osx', 'c', 'threading', 'api', 'multi', 'cocoa', 'mac', 'ip', 'objective', 'tcp']
# ['pediatrics']
# ['mapreduce', 'hadoop', 'machine', 'r', 'java', 'learning', 'predictive', 'modeling']
# ['marketing', 'specialist', 'digital']
# ['automation', 'j2ee', 'spring', 'hibernate', 'front', 'tools', 'skills', 'and', 'strong', 'java', 'devops', 'end']
# ['c', 'swift', 'mongodb', 'postgresql', 'objective']
# ['net', 'sql', 'c', 'asp', 'bootstrap', 'xml', 'ecommerce']
# ['consultant', 'technology', 'usps']
# ['native', 'development', 'back', 'game', 'foundation', 'android', 'bootstrap', 'opengl', 'unity3d', 'for', 'vr', 'end', 'responsive', 'front', 'or', 'ar', 'connecting', 'apis', 'frameworks', 'ios', 'to', 'ui']
# ['fea', 'power', 'solidworks', 'high', 'rf', 'electronics']
# ['sql', 'monetization', 'statistics', 'data']
# ['drainage', 'sewer', 'engineer', 'grading', 'water', 'utilities', 'civil', 'public', 'works', 'professional', '3d', 'ca', 'microstation', 'storm', 'drains', 'autocad', 'design', 'streets', 'pe', 'in']
# ['application', 'sqr', 'broker', 'financials', 'engine', 'sr', 'equations', 'peoplesoft', '1', '9', 'integration', 'peoplecode', 'peopletools', 'component', 'interfaces', 'systems']
# ['hybrid', 'designer', 'visual', 'interaction']
# ['programmer', 'ms', 'access', 'excel']
# ['ux', 'are', 'preferred', 'mvc', 'html5', 'javascript', 'required', 'php', 'css3', 'design']
# ['juniper', 'and', 'experience', 'router', 'switch', 'primarily', 'cisco', 'firewall']
# ['security', 'sql', 'cloud', 'aws', 't']
# ['consulting', 'sap']
# ['automation', 'tool', 'qa', 'hp', 'alm', 'tester']
# ['acl', 'diagnostic', 'networks', 'linux', 'telecom', 'cabling', 'isdn', 'ccna', 'switches', 'windows', 'testing', 'technician', 'dns', 'wireless', 'ccnp', 'routers']
# ['togaf', 'babok', 'architecture']
# ...
# ['analysis', 'security', 'cne', 'networks', 'networking', 'database', 'manager', 'cissp', 'supervision', 'switches', 'testing', 'encryption', 'research', 'management', 'routers', 'http']
# ['c', 'ios', 'for', 'cocoa', 'objective']
# ['market', '7', 'mobile', 'bloomberg', 'reuters', 'floor', 'ms', 'trade', 'windows', 'office', 'os', 'support', 'linux', 'data']
# ['redshift', 'hadoop', 'aws', 'spark', 'data', 'big']
# ['vendor', 'scripting', 'team', 'support', 'management']
# ['monitoring', 'vmware', 'shell', 'cloud', 'hadoop', '3par', 'unix', 'netbackup', 'centos', 'scripting', 'zabbix', 'veeam', 'hosts', 'rhel', 'linux', 'devops', 'data', 'big']
# ['time', 'c', 'object', 'real', 'jira', 'visual', 'extensions', 'oriented', 'windows', 'studio', 'os', 'machines', 'design', 'programming', 'svn']
# ['j2ee', 'sql', 'jdbc', 'ansi', 'consulting', 'ajax', 'development', 'java', 'pl1', 'xml']
# ['it', 'c', 'side', 'analyst', 'nav', '2015', 'ms', 'team', 'dynamics', 'new', '2013', 'consultant', 'business', 'jersey', 'functional', 'erp', 'al', 'lead', 'ax', 'manufacturing', 'navision']
# ['brms', 'java', 'jboss']
# ['intelligence', 'c', 'access', 'telecom', 'unix', 'structure', 'oop', 'stl', 'business', 'data']
# ['c', 'wcf', 'mvc']
# ['cloud', 'ruby', 'jsp', 'python', 'hp', 'orchestration', 'java', 'javascript', 'windows', 'server', 'operations', 'integration', 'linux', 'ip', 'tcp']
# ['c', 'failsafe', 'development', 'controllers', 'motor', 'drivers', 'agile', 'micro', 'pwm', 'freescale', 'hardware', 'architectures', 'pid', 'controller', 'assembler', 'scrum', 'programming', 'level', 'processors', 'arm', 'rtos']
# ['rdb', 'c', 'ms', 'degree', 'multithreading']
# ['time', 'c', 'object', 'real', 'jira', 'visual', 'extensions', 'oriented', 'windows', 'studio', 'os', 'machines', 'design', 'programming', 'svn']
# ['luxury', 'mysql', 'startup', 'background', 'aws', 'cms', 'industry', 'php', 'environment', 'crm', 'linux', 'automotive', 'apache', 'systems']
# ['solid', 'appreciation', 'knowledge', 'bootstrap', 'html5', 'based', 'angularjs', 'of', 'for', 'web', 'css3', 'design', 'applications', 'ui', 'advanced']
# ['information', 'manager', 'systems']
# ['project', 'supervision', 'development', 'javascript', 'html', 'materials', 'research', 'management', 'css']
# ['engineer', 'embedded', 'software']
# ['standardization', 'sql', 'etc', 'etl', 'processing', 'purge', 'pl', 'oracle', 'cleansing', 'server', 'merge', 'ssis', 't', 'data']
# ['express', 'cer', 'responder', 'call', 'unity', 'sip', 'emergency', 'manager', 'communications', 'unified', 'srs', 'voip', 'cucm', 'tdm', 'connections', 'cme', 'cisco', 'cuc']
# ['developer', 'oracle', 'idam']
# ['telecom', 'oss', 'provisioning']
# ['analysis', 'unix', 'java', 'windows', 'perl', 'release', 'server', 'hardware', 'management', 'sql', 'manager', 'testing', 'programming', 'datastage', 'microstrategy', 'sas', 'teradata', 'developer', 'genetic', 'oracle', 'linux']
# ['dft', 'c', 'unix', 'fpga', 'ovm', 'uvm', 'verilog', 'linux', 'design', 'digital', 'perl']
# ['master', 'oss', 'scrum']
# ['facing', 'c', 'client', 'systems', 'verilog', 'ic', 'matlab', 'products', 'engineering']
# ['streamserve', 'opentext', 'xmlout', 'xmlin', 'streamin', 'streamout']
# ['oim', 'oam', 'oud']
# ['oim', 'oam', 'access', 'suite', 'and', 'identity', '11g', 'manager', 'oracle', 'connector', 'oud', 'management']
# ['sql', 'iib', 'message', 'broker', 'unix', 'and', 'apis', 'soap', 'json', 'xml', 'ibm', 'rest']
# ['iib', 'message', 'cobol', 'cics', 'broker']
# ['analyst', 'sr', 'patient', 'accounting', 'cerner']
# ['oim', 'oimc', 'oam', 'access', 'suite', 'governance', 'qa', 'and', 'identity', '11g', 'configuration', 'oracle', 'implementation', 'of', 'development', 'uat', 'testing', 'oud', 'management']
# ['analyst', 'documentation', 'clinical']
# ['nist', 'security', 'hipaa']
# ['mobile', 'qa', 'tablet', 'science', 'manual', 'computer', 'testing', 'devices']
# ['analysis', 'financial', 'business', 'requirements', 'gathering']
# ['pmp']
# ['adobe', 'mining', 'sas', 'sql', 'telecom', 'analyst', 'basic', 'sales', 'wireless', 'web', 'data', 'modeling']
# ['phone', 'palmos', 'c', 'android', 'threading', 'structures', 'ios', 'multi', 'java', 'objective', 'windows', 'algorithms', 'data', 'blackberry']
# ['enhance', 'analytical', 'methods', 'pivots', 'and', 'experience', 'quantitative', 'supply', 'strong', 'understand', 'excel', 'chain', 'uses', 'processes', 'to', 'predict']
# ['shell', 'rman', 'oracle', 'scripting', 'linux', 'golden', 'gate', 'rac']
# ['the', 'create', 'unique', 'and', 'opportunities', 'new', 'of', 'improve', 'organization', 'operations', 'develop', 'ways', 'to']
# ['services', 'financial', 'domain']
# ['with', 'preferred', 'mobile', 'systems', 'banking', 'and', 'database', 'payment', 'industry', 'preferably', 'rds', 'or', 'internet', 'processing', 'experience', 'familiarity', 'concep', 'the', 'mysql', 'aws', 'using', 'in']
# ['sales', 'fitness']
# ['services', 'net', 'sql', 'c', 'asp', 'mobile', 'seo', 'bootstrap', 'server', 'development', 'javascript', 'reporting', 'web', 'transfer', 'marketing', 'data']
# ['networking', 'manager', 'oracle', 'printer', 'apache', 'system', 'administrator', 'hardware', 'websphere', 'windows', 'testing', 'management']
# ['c', 'ms', 'webforms', 't', '2010', 'xsd', 'and', 'winform', 'com', 'server', '2012', 'sql', 'iis', 'xsl', 'asp', 'javascript', 'xml', 'css', 'r2', 'net', '5', 'pl', 'html4', 'dhtml', '2008', '4', 'ado']
# ['business', 'analyst', 'chain', 'supply']
# ['candidate', 'must', 'influencing', 'heavily', 'an', 'skills', 'communication', 'and', 'interact', 'executive', 'strong', 'negotiation', 'leadership', 'will', 'team', 'exceptionally', 'have', 'influence', 'drive']
# ['automation', 'cloud', 'linux', 'python', 'migration', 'chef', 'system', 'scripting', 'windows', 'environment', 'support', 'devops', 'to', 'ant']
# ['services', 'js', 'hibernate', 'banking', 'jboss', 'mvc', 'bootstrap', 'ajax', 'java', 'web', 'html', 'xml', 'node', 'angular', 'css']
# ['oim', 'oimc', 'oam', 'access', 'suite', 'governance', 'and', 'identity', '11g', 'manager', 'oracle', 'oud', 'management']
# ['net', 'development', 'backend']
# ['oim', 'oam', 'identity', 'manager', 'oracle', 'oud']
# ['analyst', 'experience', 'quality', 'web', 'qc', 'testing', 'alm']
# ['desk', 'help', 'windows', 'exchange', 'linux']
# ['check', 'description']
# ['peripheral', 'networks', 'networking', 'video', 'cabling', 'hardware', 'telecommunications', 'technician', 'pc', 'management']
# ['sql', 'load', 'query', 'analyzer', 'ssis', 'script', 'vb', 'balancing']
# ['sr', 'analyst', 'cerner', 'clinical']
# ['networking', 'manager', 'oracle', 'printer', 'apache', 'system', 'administrator', 'hardware', 'websphere', 'windows', 'management']
# ['db2', 'basic', 'database', 'visual', 'oracle', 'service', 'customer', 'hardware', 'administration', 'testing', 'ibm', 'management']
# ['architect', 'oriented', 'soa', 'service']
# ['agile', 'c', 'gui', 'qt', 'scrum', 'development', 'framework', 'gwt']
# ['net', 'sql', 'c', 'e', 'commerce', 'sdlc', 'vb']
# ['drupal', 'mysql', 'lamp', 'javascript', 'php', 'html', 'apache', 'css']
# ['iseries', 'edi', 'xml', 'mq', 'rpg']
# ['sql', 'iis', 'service', 'customer', 'windows']
# ['outlook', 'manager', 'printer']
# ['security', 'network', 'cisco', 'data']
# ['warehouse', 'dynamics', 'ssrs', 'manager', 'implementation', 'gp', 'integration', 'econnect']
# ['demandware', 'developer']
# ['automated', 'python', 'tools', 'squish', 'selenium', 'java', 'linux', 'webdriver', 'qtp', 'test']
# ['see', 'description', 'job']
# ['application', 'benefits', 'sr', 'excellent', 'administrator', 'systems']
# ['services', 'net', 'agile', 'c', 'sql', 'asp', 'rest', 'or', 'sharepoint', 'html5', 'system', 'content', 'ajax', 'cms', 'javascript', 'web', 'soap', 'css3', 'jquery', 'management']
# ['analysis', 'it', 'networking', 'development', 'web', 'windows', 'project', 'systems', 'middleware', 'servers', 'hardware', 'requirements', 'aix', 'management', 'solaris', 'architecture', 'lifecycle', 'business', 'engineering', 'application', 'network', 'linux']
# ['description', 'job', 'please', 'to', 'refer']
# ['manager', 'project']
# ['analysis', 'center', 'sql', 'automated', 'analyst', 'qa', 'quick', 'case', 'scripts', 'assurance', 'quality', 'pro', 'sdlc', 'tester', 'business', 'requirements', 'testing', 'management', 'test']
# ['controls', 'winform']
# ['protocol', 'manager', 'css', 'scheduling', 'research', 'management', 'project']
# ['application', 'as400', 'developer', '400', 'iseries', 'series', 'i', 'programmer', 'as', 'development', 'os', 'rpg', 'os400']
# ['splicing', 'fiber', 'foreman']
# ['cubes', 'cognos', 'olap', 'models', 'bi', 'data']
# ['angular', 'agile', 'front', 'ux', 'mvc', 'html5', 'scrum', 'backbone', 'javascript', 'css', 'js', 'end', 'ui', 'ember', 'react']
# ['c', 'quiz', 'swift', 'excellent', 'development', 'oriented', 'questions', 'and', 'training', 'for', 'curriculum', 'interactions', 'object', 'create', 'presentation', 'online', 'programming', 'objective', 'codes', 'qa', 'skills', 'communication', 'ios', 'verbal', 'written']
# ['bi', 'ct', 'cognos', 'montville', 'role', 'fulltime', 'in']
# ['optimization', 'wan', 'networking', 'load', 'hp', 'network', 'and', 'bluecat', 'design', 'assessments', 'balancing']
# ['grants', 'sharepoint', 'bootstrap', 'backbone', 'javascript', 'node', 'management', 'angular']
# ['sql', 'teradata', 'or', 'db2', 'python', 'scala', 'oracle', 'java']
# ['sql', 'developer']
# ['not', 'travel', 'available', 'required', 'telecommuting']
# ['engineer', 'electrical']
# ['support', 'analyst', 'desktop']
# ['not', 'travel', 'available', 'required', 'telecommuting']
# ['not', 'travel', 'available', 'required', 'telecommuting']
# ['not', 'travel', 'available', 'required', 'telecommuting']
# ['not', 'travel', 'available', 'required', 'telecommuting']
# ['preferred', 'strong', 'r', 'payroll', 'years', 'cpp', 'federal', 'knowledge', 'and', 'cycle', 'working', 'processing', 'experience', 'of', 'best', 'state', '6', 'qualifications', 'practices', 'full', '4']
# ['analysis', 'agile', 'security', 'sql', 'warehouse', 'qa', 'analyst', 'manager', 'scrum', 'assurance', 'quality', 'tester', 'testing', 'data', 'project']
# ['shell', 'sql', 'trading', 'pl', 'informatica', 'energy']
# ['not', 'travel', 'available', 'required', 'telecommuting']
# ['udp', 'games', 'c', 'mmo', 'networking', 'packet', 'prioritization', 'multi', 'player', 'algorithms', 'game', 'data', 'tcp']
# ['not', 'travel', 'available', 'required', 'telecommuting']
# ['python', 'sql']
# ['not', 'travel', 'available', 'required', 'telecommuting']
# ['analysis', 'warehouse', 'hadoop', 'help', 'service', 'development', 'project', 'desk', 'informatica', 'release', 'customer', 'requirements', 'data', 'management', 'metrics', 'outlook', 'change', 'sdlc', 'business', 'testing', 'http', 'net', 'datastage', 'teradata', 'genetic', 'configuration']
# ['market', 'or', 'risk', 'commodity', 'energy', 'credit', 'domain']
# ['net', 'continuous', 'visual', 'endur', 'scripting', 'release', 'deployment', 'etrm', 'build', 'tfs', 'java', 'studio', 'integration', 'devops', 'powershell', 'management', 'openlink']
# ['not', 'travel', 'available', 'required', 'telecommuting']
# ['not', 'travel', 'available', 'required', 'telecommuting']
# ['engineer', 'senior', 'software']
# ['not', 'travel', 'available', 'required', 'telecommuting']
# ['not', 'travel', 'available', 'required', 'telecommuting']
# ['not', 'travel', 'available', 'required', 'telecommuting']
# ['not', 'travel', 'available', 'required', 'telecommuting']
# ['not', 'travel', 'available', 'required', 'telecommuting']
# ['not', 'travel', 'available', 'required', 'telecommuting']
# ['not', 'travel', 'available', 'required', 'telecommuting']
# ['not', 'travel', 'available', 'required', 'telecommuting']
# ['not', 'travel', 'available', 'required', 'telecommuting']
# ['not', 'travel', 'available', 'required', 'telecommuting']
# ['not', 'travel', 'available', 'required', 'telecommuting']
# ['not', 'travel', 'available', 'required', 'telecommuting']
# ['not', 'travel', 'available', 'required', 'telecommuting']
# ['udp', 'games', 'c', 'mmo', 'networking', 'packet', 'prioritization', 'multi', 'player', 'algorithms', 'game', 'data', 'tcp']
# ['project', 'wan', 'networks', 'protocol', 'engineer', 'protocols', 'http', 'network', 'lan', 'development', 'hardware', 'architecture', 'html', 'switches', 'wireless', 'dns', 'cisco', 'management', 'routers', 'css']
# ['analysis', 'planning', 'database', 'oracle', 'modeling', 'architecture', 'capacity', 'management', 'project']
# ['not', 'travel', 'available', 'required', 'telecommuting']
# ['not', 'travel', 'available', 'required', 'telecommuting']
# ['not', 'travel', 'available', 'required', 'telecommuting']
# ['not', 'travel', 'available', 'required', 'telecommuting']
# ['analysis', 'telecom', 'knowledge', 'oracle', 'consulting', 'content', 'excel', 'development', 'sales', 'architecture', 'recruiter', 'data', 'management', 'project']
# ['security', 'bridges', 'manager', 'database', 'associates', 'supervision', 'smtp', 'computer', 'management']
# ['r2', '2012', 'sql', 'server', '2008']
# ['metrics', 'director', 'telecom', 'powerpoint', 'excel', 'development', 'hardware', 'recruiter', 'management', 'http']
# ['not', 'travel', 'available', 'required', 'telecommuting']
# ['not', 'travel', 'available', 'required', 'telecommuting']
# ['collection', 'data', 'telecom', 'manager']
# ['engineer', 'php', 'senior', 'software']
# ['net', 'security', 'protocol', 'citrix', 'developer', 'api', 'consulting', 'development', 'java', 'architecture', 'javascript', 'pl1', 'windows', 'vmware', 'management', 'http']
# ['not', 'travel', 'available', 'required', 'telecommuting']
# ['not', 'travel', 'available', 'required', 'telecommuting']
# ['net', 'developer', 'desk', 'synon', 'help', 'development', 'architecture', 'forth', 'rpg', 'ibm', 'management', 'http']
# ['not', 'travel', 'available', 'required', 'telecommuting']
# ['support', 'desktop']
# ['analysis', 'center', 'analytical', 'graphics', 'analyst', 'service', 'excel', 'development', 'ms', 'salesforce', 'administration', 'lotus', 'project', 'call', 'query', 'knowledge', 'database', 'customer', 'office', 'server', 'data', 'management', 'notes', 'sql', 'outlook', 'manager', 'scheduling', 'skills', 'qa', 'assurance', 'quality']
# ['not', 'travel', 'available', 'required', 'telecommuting']
# ['not', 'travel', 'available', 'required', 'telecommuting']
# ['wan', 'analytical', 'skills', 'video', 'oracle', 'lan', 'testing', 'cisco', 'ccnp', 'project']
# ['not', 'travel', 'available', 'required', 'telecommuting']
# ['not', 'travel', 'available', 'required', 'telecommuting']
# ['not', 'travel', 'available', 'required', 'telecommuting']
# ['not', 'travel', 'available', 'required', 'telecommuting']
# ['not', 'travel', 'available', 'required', 'telecommuting']
# ['project', 'analytical', 'skills', 'qa', 'telecom', 'database', 'change', 'release', 'supervision', 'development', 'architecture', 'recruiter', 'scheduling', 'sdlc', 'validation', 'testing', 'management', 'http']
# ['not', 'travel', 'available', 'required', 'telecommuting']
# ['netscaler', 'ccnp', 'wan', 'wifi', 'bgp', 'load', 'citrix', 'protocols', 'asa', 'ncs', 'ccie', 'lan', 'switches', 'balancers', 'devices', 'firewalls', 'f5', 'cisco', 'vpn', 'routers']
# ['js', 'html5', 'bootsrap', 'css3', 'jquery', 'angular']
# ['sql', 'hadoop', 'hive']
# ['not', 'travel', 'available', 'required', 'telecommuting']
# ['analysis', 'analytical', 'analyst', 'python', 'series', 'development', 'websphere', 'windows', 'powershell', 'foundation', 'perl', 'middleware', 'management', 'sql', 'manager', 'testing', 'apache', 'skills', 'consulting', 'mq', 'linux', 'video']
# ['not', 'travel', 'available', 'required', 'telecommuting']
# ['not', 'travel', 'available', 'required', 'telecommuting']
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-35-34056bc26bfd> in <module>()
#       1 import re
#       2 for i in range(0,len(data.index)):
# ----> 3     print(list(set(re.findall(r"[\w']+",data['sector'][i].lower()))))
#
# AttributeError: 'float' object has no attribute 'lower'

# %%
len(data.index)
# Out:
# 21920

# %%
import re
skill=[]
skill=list(set(re.findall(r"[\w']+",data['sector'][0].lower())))
for i in range(1,100):
    skill.extend(list(set(re.findall(r"[\w']+",data['sector'][i].lower()))))
print(skill)
# Out:
# ['as2', 'edi', 'trustedlink', 'van', 'sql', 'netezza', 'etl', 'oracle', 'informatica', 'exchange', 'b2b', 'data', 'angular', 'dynamics', 'toronto', 'manager', 'usd', 'ax', '135k', 'microsoft', 'project', 'net', 'sql', 'c', 'asp', 'mvc', 'javascript', 'language', 'visualization', 'python', 'scala', 'machine', 'processing', 'iot', 'analytics', 'java', 'learning', 'deep', 'spark', 'nlp', 'natural', 'industrial', 'predictive', 'data', 'modeling', 'agile', 'sql', 'or', 'unix', 'oracle', 'concurrent', 'multi', 'java', 'methodology', 'sdlc', 'linux', 'programming', 'threaded', 'administrator', 'linux', 'system', 'xactly', 'analyst', 'financial', 'commission', 'sales', 'callidus', 'compensation', 'tuecomp', 'application', 'drupal', 'experience', 'strong', 'development', 'in', 'tool', 'scripting', 'ssis', 'aws', 'operations', 'it', 'pmo', 'pay', 'supporting', 'retail', 'finance', 'is', 't', 'purchase', 'support', 'to', 'net', 'c', 'asp', 'html5', 'content', 'javascript', 'management', 'systems', 'security', 'networking', 'telecom', 'peripherals', 'printer', 'laptop', 'supervision', 'hardware', 'technician', 'wan', 'c', 'networking', 'software', 'engineer', 'development', 'java', 'testing', 'ecommerce', 'programming', 'management', 'project', 'analysis', 'reports', 'ad', 'data', 'bi', 'hoc', 'specialist', 'personalization', 'ariba', 'supply', 'consulting', 'excel', 'development', 'chain', 'recruiter', 'html', 'lifecycle', 'crm', 'sap', 'testing', 'research', 'management', 'http', 'java', 'mongodb', 'net', 'working', 'with', 'demonstrated', 'interpersonal', 'skills', 'communication', 'and', 'experience', 't', 'verbal', 'salesforce', 'ipc', 'written', 'qualifications', 'ability', 'analysis', 'security', 'networking', '7', 'and', 'system', 'administrator', 'recovery', 'ccna', 'backup', 'development', 'hardware', 'exchange', 'windows', 'dns', 'ip', 'tcp', 'systems', 'performance', 'networks', 'networking', 'engineer', 'network', 'system', 'scheduling', 'ccie', 'cisco', 'firewall', 'java', 'developer', 'years', 'it', 'or', 'an', 'systems', '3', 'experience', 'field', 'support', "bachelor's", 'information', 'technology', 'required', 'equivalent', 'work', 'of', 'degree', 'qualifications', 'related', 'in', 'sdlc', 'net', 'c', 'asp', 'meeting', 'skills', 'and', 'excellent', 'goto', 'excel', 'degree', 'management', 'bachelors', 'project', 'or', 'maven', 'rake', 'make', 'ant', 'rails', 'mobile', 'on', 'ruby', 'html5', 'aws', 'javascript', 'web', 'developer', 'mysql', 'development', 'php', 'linux', 'programming', 'apache', 'networking', 'windows', 'wan', 'and', 'servers', 'server', 'backup', 'domain', 'vmware', 'management', 'switching', 'active', 'experience', 'eam', 'lan', 'of', 'support', 'user', 'ip', 've', 'directory', '5', '50', 'environment', 'cisco', 'rails', 'frontend', 'on', 'ruby', 'mysql', 'aws', 'development', 'javascript', 'backend', 'maven', 'jenkins', 'aws', 'linux', 'devops', 'shotgun', 'software', 'unix', 'windows7', 'os', 'linux', 'mac', 'analysis', 'application', 'project', 'networking', 'engineer', 'protocols', 'python', 'basic', 'network', 'unix', 'quality', 'computer', 'linux', 'management', 'perl', 'db2', 'etl', 'migration', 'vsam', 'data', 'ibm', 'sql', 'c', 'basic', 'visual', 'usb', 'serial', 'bluetooth', 'ethernet', 'wan', 'c', 'networking', 'software', 'engineer', 'development', 'java', 'testing', 'ecommerce', 'programming', 'management', 'project', 'analysis', 'sql', 'intelligence', 'metrics', 'development', 'business', 'requirements', 'research', 'java', 'developer', 'automation', 'linux', 'aws', 'windows', 'devops', 'aem', 'cq5', 'manager', 'project', 'security', 'software', 'peripherals', 'laptop', 'printer', 'desktop', 'hardware', 'computer', 'technician', 'systems', 'contracts', 'ar', 'service', 'coordination', 'uat', 'architect', 'otc', 'solution', 'crp', 'business', 'apex', 'solutions', 'data', 'agile', 'b2b', 'or', 'drupal', 'tools', 'b', 'b2c', 'cms', 'a', 'ios', 'development', 'android', 'mobile', 'sql', 'deve ...

# %%
import pandas as pd
import numpy as  np
import re
data=pd.read_csv("mini.csv",encoding='latin-1')
list(set(re.split(',|-',data['sector'][4])))
column=[]
for i in range(0,len(data.index)):
    if type(data['sector'][i]) is str:
        for e in re.split(',|-|/',data['sector'][i].lower()):
            column.extend(re.findall(r'\w+[.]\w+|\w#|\w+|w[++]', e))
#print(list(set(column)))

# %%
import re
for i in range(0,len(data.index)):
    if type(data['sector'][i]) is str:
        #print(list(set(re.findall(r"[\w']+",data['sector'][i].lower()))))
# Out:
#   File "<ipython-input-6-9dd853f4daa5>", line 4
#     #print(list(set(re.findall(r"[\w']+",data['sector'][i].lower()))))
#                                                                       ^
# SyntaxError: unexpected EOF while parsing

# %%
len(data.index)
# Out:
# 21920

# %%
import re
skill=[]
skill=list(set(re.findall(r"[\w']+",data['sector'][0].lower())))
for i in range(1,len(data.index)):
    if type(data['sector'][i]) is str:
        skill.extend(list(set(re.findall(r"[\w']+",data['sector'][i].lower()))))
skill = [e for e in skill if e not in ('in','on','or','an','with','written','7','required','automated','learning','stored','it','of','statements','structure','installation','is','t', 'plus', '5','s','z','a','ad')]
skill = ['.net' if x=='net' else x for x in skill]
print(list(set(skill)))

# %%
re.findall(r"[\w']+",data['sector'][0].lower())
# Out:
# ['edi', 'trustedlink', 'as2', 'van', 'edi', 'trustedlink', 'as2', 'van']

# %%
columns=skill
index=range(0,21920)
dataframe=pd.DataFrame(index=index,columns=columns)
dataframe['job']=pd.Series(index=dataframe.index)
for j in range(0,21920):
    for p in list(set(re.findall(r"[\w']+",data['sector'][j].lower()))):
        print(p)
        if p in columns:
            dataframe[p][j]='yes'
            print(dataframe[p][j])
    dataframe['job'][j]=data['job_title'][j]
print(dataframe)
# Out:
# van
# nan
# as2
# nan
# edi
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-48-13dc6685715e> in <module>()
#       7         print(p)
#       8         if p in columns:
# ----> 9             dataframe[p][j]='yes'
#      10             print(dataframe[p][j])
#      11     dataframe['job'][j]=data['job_title'][j]
#
# ~\Anaconda3\envs\chandrahas\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    2517         else:
#    2518             # set column
# -> 2519             self._set_item(key, value)
#    2520
#    2521     def _setitem_slice(self, key, value):
#
# ~\Anaconda3\envs\chandrahas\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    2584         self._ensure_valid_index(value)
#    2585         value = self._sanitize_column(key, value)
# -> 2586         NDFrame._set_item(self, key, value)
#    2587
# ...

# %%
for p in list(set(re.findall(r"[\w']+",data['sector'][0].lower()))):
    print(p)
# Out:
# van
# as2
# edi
# trustedlink

# %%
#df.set_value('C', 'x', 10)
dataframe['van'][0]=10
print(dataframe['van'][0])
# Out:
# nan

# %%
for i in range(0,1):
    if(type(data['sector'][28]) is str):
        for e in re.split(',|-|/|;|and|or',data['sector'][28].lower()):
            for p in re.findall(r'\w\++|\w+[\s,.]\w+[\s,.]\w+[\s,.]\w+|\w+[\s,.]\w+[\s,.]\w+|\w+[\s,.]\w+|\w#|\w+|\.\w+',e):
                print(p)
# Out:
# apache
# developer
# development
# linux
# mysql
# mysql
# php
# programming

# %%
skill=[]
column=[]
for i in range(0,75):
    if(type(data['sector'][i]) is str):
        for e in re.split(',|-|/|;|and|or',data['sector'][i].lower()):
            for p in re.findall(r'\w\++|\w+[\s,.]\w+[\s,.]\w+[\s,.]\w+|\w+[\s,.]\w+[\s,.]\w+|\w+[\s,.]\w+|\w#|\w+|\.\w+',e):
                skill.append(p)
column=list(set(skill))
print(column)

# %%
job_data=[]
for i in range(0,len(data.index)):
    for e in re.split(',|-|/',data['sector'][i].lower()):
        job_data.extend(re.findall(r'\w\++|\w+[\s,.]\w+[\s,.]\w+[\s,.]\w+|\w+[\s,.]\w+[\s,.]\w+|\w+[\s,.]\w+|\w#|\w+',e))
print(list(set(job_data)))
#for i in range(0,20):
#print(re.split(',|-|/',data['sector'][5].lower()))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-255df3d1f8c7> in <module>()
#       1 job_data=[]
#       2 for i in range(0,len(data.index)):
# ----> 3     for e in re.split(',|-|/',data['sector'][i].lower()):
#       4         job_data.extend(re.findall(r'\w\++|\w+[\s,.]\w+[\s,.]\w+[\s,.]\w+|\w+[\s,.]\w+[\s,.]\w+|\w+[\s,.]\w+|\w#|\w+',e))
#       5 print(list(set(job_data)))
#
# AttributeError: 'float' object has no attribute 'lower'

# %%
skill=[]
for i in range(0,100):
    if(type(data['sector'][i]) is str):
        for e in re.split(',|-|/|;',data['sector'][i]):
            for p in list(set(re.findall(r'(.*)',e.lower()))):
                skill.append(p)
            
print(skill)
# Out:
# ['', 'edi', '', ' trustedlink', ' as2', '', ' van ', '', ' edi', '', '', ' trustedlink', ' as2', '', '', ' van', '', 'etl informatica b2b data exchange netezza oracle sql', '', 'angular', '', 'microsoft dynamics ax', '', ' project manager ', ' toronto ', '', '', '', ' $135k usd', '', 'c#', ' asp.net', '', '', ' sql', '', ' javascript', '', ' mvc ', '', ' c#', ' asp.net', '', '', ' sql', '', ' javascript', '', ' mvc', 'machine learning', '', '', ' java', '', ' scala', ' spark', '', '', ' predictive modeling', ' industrial iot analytics', '', '', ' data visualization', '', ' natural language processing (nlp)', '', ' python', ' deep learning ', '', '', ' machine learning', '', ' java', '', ' scala', ' spark', '', '', ' predictive modeling', ' industrial iot analytics', '', '', ' data visualization', '', ' natural language processing (nlp)', '', ' python', '', ' deep learning', '', 'java', '', ' linux', '', 'unix', '', ' sdlc', '', ' multi', '', 'threaded or concurrent programming', '', 
# ...

# %%
for i in range(0,len(data.index)):
    for e in re.split(',|-|/|;',data['sector'][i]):
        print(re.findall(r"([^]+)\s*:\s*([^]+)",e))
# Out:
# ['EDI']
# ['TrustedLink']
# ['AS2']
# ['VAN']
# ['EDI']
# ['TrustedLink']
# ['AS2']
# ['VAN']
# ['ETL', 'Informatica', 'B2B', 'Data', 'Exchange', 'Netezza', 'Oracle', 'SQL']
# ['Angular']
# ['Microsoft', 'Dynamics', 'AX']
# ['Project', 'Manager']
# ['Toronto']
# []
# ['$135k', 'USD']
# ['C#']
# ['ASP.NET']
# ['SQL']
# ['JavaScript']
# ['MVC']
# ['C#']
# ['ASP.NET']
# ['SQL']
# ['JavaScript']
# ['MVC']
# ['Machine', 'Learning']
# ['Java']
# ['Scala']
# ['SPARK']
# ['Predictive', 'Modeling']
# ['Industrial', 'IoT', 'Analytics']
# ['Data', 'Visualization']
# ['Natural', 'Language', 'Processing', 'NLP']
# ['Python']
# ['Deep', 'Learning']
# ['Machine', 'Learning']
# ['Java']
# ['Scala']
# ['SPARK']
# ['Predictive', 'Modeling']
# ['Industrial', 'IoT', 'Analytics']
# ['Data', 'Visualization']
# ['Natural', 'Language', 'Processing', 'NLP']
# ['Python']
# ['Deep', 'Learning']
# ['Java']
# ['Linux']
# ['Unix']
# ['SDLC']
# ['Multi']
# ['Threaded', 'or', 'Concurrent', 'Programming']
# ...

# %%
import itertools as it
my = []
row=[]
dataframe=pd.DataFrame(columns=column)
for i in range(0,75):
    my=[]
    if(type(data['sector'][i]) is str):
        row=[]
        for p in re.split(',|-|/|;|and|or',data['sector'][i].lower()):
            row.extend(re.findall(r'\w\++|\w+[\s,.]\w+[\s,.]\w+[\s,.]\w+|\w+[\s,.]\w+[\s,.]\w+|\w+[\s,.]\w+|\w#|\w+|\.\w+',p))
        for e in column:
            if e in row:
                my.append('1')
            else:
                my.append('0')
        dataframe.loc[i]=my;

dataframe

# %%
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()
model.fit(dataframe,job)
predicted= model.predict(dataframe[2:3])
print(predicted)
# Out:
# ['Angular developer']

# %%
job=[]
job=data['job_title'][0:75]
job
# Out:
# 0                                           EDI Analyst
# 1                             Informatica ETL Developer
# 2                                     Angular developer
# 3                Microsoft Dynamics AX, Project Manager
# 4                                    Software Developer
# 5                             Machine Learning Engineer
# 6                                   Core Java Developer
# 7                            Linux System Administrator
# 8                                    Commission Analyst
# 9                                      Drupal Developer
# 10           SQL/SSIS Developer (AWS Migration Project)
# 11       PMO (for Purchase to Pay Support) OR Purchaser
# 12                                Senior .NET Developer
# 13                       Field Service Technician II US
# 14                        Software Development Engineer
# 15               Business Operations /Financial Analyst
# 16                           Personalization Specialist
# ...

# %%
from sklearn.naive_bayes import GaussianNB
import numpy as np
x= np.array([[-3,7],[1,5], [1,2], [-2,0], [2,3], [-4,0], [-1,1], [1,1], [-2,2], [2,7], [-4,1], [-2,7]])
Y = np.array([3, 3, 3, 3, 4, 3, 3, 4, 3, 4, 4, 4])
model = GaussianNB()
model.fit(x, Y)
# Out:
# GaussianNB(priors=None)

# %%
dataframe[2:3]
# Out:
#   lotus rake solution architect ecommerce quality aws visual basic e.g  \
# 2     0    0                  0         0       0   0            0   0
#
#   service data structure        ...         supp user environment security  \
# 2       0              0        ...            0                0        0
#
#   bridges ting it bi tools ccna personalization specialist  \
# 2       0       0        0    0                          0
#
#   predictive modeling commission analyst
# 2                   0                  0
#
# [1 rows x 329 columns]

# %%
skill=['c++']
pre=[]
for e in column:
    if e in skill:
        pre.append('1')
    else:
        pre.append('0')

data1=pd.DataFrame(columns=column)
data1.loc[0]=pre
predicted1=model.predict(data1[0:1])
print(predicted1)
# Out:
# ['Personalization Specialist']

# %%
from sklearn import svm
model = svm.SVC(kernel='linear', C=1, gamma=100) 
model.fit(dataframe, job)
model.score(dataframe, job)
predicted2= model.predict(data1[0:1])
print(predicted2)
# Out:
# ['Software Development Engineer']

# %%
from sklearn import tree
model = tree.DecisionTreeClassifier(criterion='entropy') 
model.fit(dataframe, job)
model.score(dataframe, job)
predicted3= model.predict(data1[0:1])
print(predicted3)
# Out:
# ['Architectural Designer']

# %%
data
# Out:
#       country_code  date_added             job_board  \
# 0               US  11/11/2016  https://www.dice.com
# 1               US  11/11/2016  https://www.dice.com
# 2               US  11/11/2016  https://www.dice.com
# 3               US  11/12/2016  https://www.dice.com
# 4               US  11/11/2016  https://www.dice.com
# 5               US  11/11/2016  https://www.dice.com
# 6               US  11/11/2016  https://www.dice.com
# 7               US  11/11/2016  https://www.dice.com
# 8               US  11/11/2016  https://www.dice.com
# 9               US  11/12/2016  https://www.dice.com
# 10              US  11/12/2016  https://www.dice.com
# 11              US  11/11/2016  https://www.dice.com
# 12              US  11/11/2016  https://www.dice.com
# 13              US  11/12/2016  https://www.dice.com
# 14              US  11/12/2016  https://www.dice.com
# 15              US  11/12/2016  https://www.dice.com
# 16              US  11/11/2016  https://www.dice.com
# ...

# %%
import pandas as pd;
import numpy as np;
sal_data=pd.read_csv("Wuzzuf_Job_Posts.csv")
import plotly.plotly as py
import plotly.graph_objs as go
py.sign_in('Chandur626','RH3T34HI2BvNXYSybfaL')
trace1 = go.Bar(
    x=sal_data['job_title'][0:75],
    y=sal_data['salary_minimum'],
    name='min salary'
)
trace2 = go.Bar(
    x=sal_data['job_title'][0:75],
    y=sal_data['salary_maximum'],
    name='max salary'
)

data = [trace1, trace2]
layout = go.Layout(
    barmode='stack'
)

fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='stacked-bar')
# Out:
# The draw time for this plot will be slow for clients without much RAM.
# C:\Users\Chandu\Anaconda3\envs\chandrahas\lib\site-packages\plotly\api\v1\clientresp.py:40: UserWarning:
#
# Estimated Draw Time Slow
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~Chandur626/10.embed" height="525px" width="100%"></iframe>

# %%
trace1 = go.Bar(
    x=sal_data['job_title'][75:150],
    y=sal_data['salary_minimum'],
    name='min salary'
)
trace2 = go.Bar(
    x=sal_data['job_title'][75:150],
    y=sal_data['salary_maximum'],
    name='max salary'
)

data = [trace1, trace2]
layout = go.Layout(
    barmode='stack'
)

fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='stacked-bar')
# Out:
# The draw time for this plot will be slow for clients without much RAM.
# C:\Users\Chandu\Anaconda3\envs\chandrahas\lib\site-packages\plotly\api\v1\clientresp.py:40: UserWarning:
#
# Estimated Draw Time Slow
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~Chandur626/10.embed" height="525px" width="100%"></iframe>

# %%
sal_data
# Out:
#              id                      city  \
# 0       516e4ed                      Ciro
# 1      a361ef59                     Cairo
# 2      7226ce78                     Cairo
# 3      f4b2bcd6                     Cairo
# 4      3fee6f73                Alexandria
# 5      22eb5fcb                     Cairo
# 6      e9b78c6e      6 th of October city
# 7      6f23fec0                    cairo,
# 8      a47f2d65                     Cairo
# 9      55299fb0                Alexandria
# 10     4fc087da                     Cairo
# 11     c954f574                     Cairo
# 12      20826d1                     Cairo
# 13     f35e9404                     Cairo
# 14     463f5324                     Cairo
# 15      bf7f22f                     Cairo
# 16     c0ab218a                     Cairo
# 17     ddae1132                     Cairo
# 18     16f2c297           all Governments
# 19     9066b039                     Cairo
# 20     2b148b35                     Cairo
# ...
